# %%
import pandas as pd

# %%
#1. Load the Amazon Prime dataset into a Pandas DataFrame.

df = pd.read_csv("Downloads/amazon_prime_video_data.csv")

# %%
#2. Display the first 10 records of the dataset.

df.head(10)
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
# 5        5006        Movie        Drama      Hindi          2010
# 6        5007        Movie       Action    Kannada          2019
# 7        5008        Movie       Sci-Fi     Telugu          2020
# 8        5009        Movie       Comedy    English          2005
# 9        5010        Movie     Thriller    Kannada          2017
#
#    duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                80          NaN          U  Australia  2022-08-21
# 1               165          7.3        U/A     Canada  2023-03-23
# ...

# %%
#3. Display the last 5 records of the dataset.

df.tail()
# Out:
#      content_id content_type    genre   language  release_year  \
# 601        5510        Movie   Action  Malayalam          2015
# 602        5349        Movie   Action     Telugu          2018
# 603        5339        Movie   Action  Malayalam          2009
# 604        5434        Movie  Romance     Telugu          2013
# 605        5491      TV Show  Romance    English          2020
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 601               169          7.8          A  Australia  2023-07-15
# 602               119          4.9          A         UK  2021-03-02
# 603                97          6.7          A  Australia  2023-11-29
# 604               162          9.3        U/A         UK  2023-09-30
# 605               140          6.0          U  Australia  2022-05-29
#
#      views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 601           91.25                31.0            8.26             Basic
# ...

# %%
#4. Check the total number of rows and columns.

df.shape
# Out:
# (606, 16)

# %%
#5. Display all column names with their data types.

df.dtypes
# Out:
# content_id              int64
# content_type           object
# genre                  object
# language               object
# release_year            int64
# duration_minutes        int64
# imdb_rating           float64
# age_rating             object
# country                object
# added_date             object
# views_millions        float64
# avg_watch_time_min    float64
# likes_millions        float64
# subscription_plan      object
# is_trending            object
# revenue_millions      float64
# dtype: object

# %%
#6. Generate summary statistics for numerical columns.

df.describe()
# Out:
#         content_id  release_year  duration_minutes  imdb_rating  \
# count   606.000000    606.000000        606.000000   566.000000
# mean   5301.823432   2014.714521        119.330033     6.916961
# std     173.127136      5.712624         34.121949     1.447780
# min    5001.000000   2005.000000         60.000000     4.500000
# 25%    5152.250000   2010.000000         91.250000     5.600000
# 50%    5303.500000   2015.000000        120.000000     6.900000
# 75%    5451.750000   2020.000000        147.000000     8.100000
# max    5600.000000   2024.000000        179.000000     9.500000
#
#        views_millions  avg_watch_time_min  likes_millions  revenue_millions
# count      606.000000          570.000000      606.000000        606.000000
# mean        61.660677           86.482456        7.474241         25.315792
# std         33.650763           41.767713        4.332711         13.654265
# min          0.150000           20.000000        0.010000          0.140000
# ...

# %%
#7. Identify columns containing missing values.

df.isna().sum()
# Out:
# content_id             0
# content_type           0
# genre                  0
# language               0
# release_year           0
# duration_minutes       0
# imdb_rating           40
# age_rating             0
# country                0
# added_date             0
# views_millions         0
# avg_watch_time_min    36
# likes_millions         0
# subscription_plan      0
# is_trending            0
# revenue_millions       0
# dtype: int64

# %%
#8. Count missing values in each column.

df.isna().sum()
# Out:
# content_id             0
# content_type           0
# genre                  0
# language               0
# release_year           0
# duration_minutes       0
# imdb_rating           40
# age_rating             0
# country                0
# added_date             0
# views_millions         0
# avg_watch_time_min    36
# likes_millions         0
# subscription_plan      0
# is_trending            0
# revenue_millions       0
# dtype: int64

# %%
#9. Calculate the percentage of missing values in imdb_rating.

print(df['imdb_rating'].isnull().sum()/len(df) * 100)
# Out:
# 6.6006600660066

# %%
#10. Fill missing imdb_rating values using the mean.

df["imdb_rating"].fillna(df["imdb_rating"].mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17792\3772307510.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["imdb_rating"].fillna(df["imdb_rating"].mean(), inplace=True)

# %%
#11. Fill missing avg_watch_time_min values using the median.

df["avg_watch_time_min"].fillna(df["avg_watch_time_min"].mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17792\68562941.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["avg_watch_time_min"].fillna(df["avg_watch_time_min"].mean(), inplace=True)

# %%
#12. Verify that missing values are handled.

df.isna().sum()
# Out:
# content_id            0
# content_type          0
# genre                 0
# language              0
# release_year          0
# duration_minutes      0
# imdb_rating           0
# age_rating            0
# country               0
# added_date            0
# views_millions        0
# avg_watch_time_min    0
# likes_millions        0
# subscription_plan     0
# is_trending           0
# revenue_millions      0
# dtype: int64

# %%
#13. Check if duplicate records exist.

df.duplicated().sum()
# Out:
# 6

# %%
#14. Count total duplicate rows.

df.duplicated().sum()
# Out:
# 6

# %%
#15. Display duplicate records.

df[df.duplicated()]
# Out:
#      content_id content_type     genre   language  release_year  \
# 600        5482      TV Show  Thriller    English          2009
# 601        5510        Movie    Action  Malayalam          2015
# 602        5349        Movie    Action     Telugu          2018
# 603        5339        Movie    Action  Malayalam          2009
# 604        5434        Movie   Romance     Telugu          2013
# 605        5491      TV Show   Romance    English          2020
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 600                60          5.6          U      India  2021-03-15
# 601               169          7.8          A  Australia  2023-07-15
# 602               119          4.9          A         UK  2021-03-02
# 603                97          6.7          A  Australia  2023-11-29
# 604               162          9.3        U/A         UK  2023-09-30
# 605               140          6.0          U  Australia  2022-05-29
#
# ...

# %%
#16. Remove duplicate rows permanently.

df.drop_duplicates(inplace=True)

# %%
#17. Verify the dataset shape after removing duplicates.

df.shape
# Out:
# (600, 16)

# %%
#18. Find the number of unique values in content_type.

df["content_type"].nunique()
# Out:
# 2

# %%
#19. Find the number of unique values in genre.

df["genre"].nunique()
# Out:
# 7

# %%
#20. Display all unique languages.

df["language"].unique()
# Out:
# array(['Tamil', 'Malayalam', 'Telugu', 'Hindi', 'Kannada', 'English'],
#       dtype=object)

# %%
#21. Count content by genre.

df["genre"].value_counts()
# Out:
# genre
# Documentary    100
# Drama          100
# Sci-Fi          95
# Action          87
# Romance         73
# Thriller        73
# Comedy          72
# Name: count, dtype: int64

# %%
#22. Count content by language.

df["language"].value_counts()
# Out:
# language
# Tamil        111
# Malayalam    106
# Hindi        104
# English      103
# Telugu        92
# Kannada       84
# Name: count, dtype: int64

# %%
#23. Filter content with imdb_rating greater than 8.

df[df["imdb_rating"] > 8]
# Out:
#      content_id content_type        genre   language  release_year  \
# 2          5003        Movie  Documentary  Malayalam          2024
# 4          5005      TV Show  Documentary  Malayalam          2021
# 10         5011      TV Show        Drama  Malayalam          2014
# 11         5012      TV Show        Drama    English          2014
# 12         5013        Movie       Sci-Fi  Malayalam          2011
# ..          ...          ...          ...        ...           ...
# 588        5589      TV Show  Documentary    English          2013
# 589        5590      TV Show        Drama  Malayalam          2012
# 592        5593        Movie  Documentary      Tamil          2009
# 594        5595      TV Show       Sci-Fi     Telugu          2017
# 595        5596      TV Show       Action      Tamil          2024
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 2                 129          9.5          A         UK  2023-10-05
# ...

# %%
#24. Filter content with views_millions greater than 50.

df[df["views_millions"] > 50]
# Out:
#      content_id content_type        genre   language  release_year  \
# 0          5001        Movie      Romance      Tamil          2014
# 3          5004      TV Show       Comedy     Telugu          2016
# 4          5005      TV Show  Documentary  Malayalam          2021
# 5          5006        Movie        Drama      Hindi          2010
# 6          5007        Movie       Action    Kannada          2019
# ..          ...          ...          ...        ...           ...
# 591        5592        Movie       Sci-Fi    English          2005
# 593        5594        Movie      Romance  Malayalam          2009
# 595        5596      TV Show       Action      Tamil          2024
# 596        5597        Movie       Sci-Fi      Hindi          2017
# 599        5600        Movie       Comedy    English          2024
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                  80     6.916961          U  Australia  2022-08-21
# ...

# %%
#25. Filter content released after 2018.

df[df["release_year"] > 2018]
# Out:
#      content_id content_type        genre   language  release_year  \
# 2          5003        Movie  Documentary  Malayalam          2024
# 4          5005      TV Show  Documentary  Malayalam          2021
# 6          5007        Movie       Action    Kannada          2019
# 7          5008        Movie       Sci-Fi     Telugu          2020
# 13         5014        Movie       Sci-Fi    Kannada          2020
# ..          ...          ...          ...        ...           ...
# 582        5583      TV Show        Drama    Kannada          2020
# 590        5591        Movie       Action      Tamil          2019
# 595        5596      TV Show       Action      Tamil          2024
# 597        5598        Movie     Thriller     Telugu          2021
# 599        5600        Movie       Comedy    English          2024
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 2                 129     9.500000          A         UK  2023-10-05
# ...

# %%
#26. Filter content belonging to Action or Thriller genre.

df[df["genre"].isin(["Action","Thriller"])]
# Out:
#      content_id content_type     genre   language  release_year  \
# 1          5002      TV Show    Action  Malayalam          2010
# 6          5007        Movie    Action    Kannada          2019
# 9          5010        Movie  Thriller    Kannada          2017
# 15         5016      TV Show    Action     Telugu          2016
# 16         5017        Movie    Action    Kannada          2015
# ..          ...          ...       ...        ...           ...
# 584        5585        Movie  Thriller      Hindi          2015
# 585        5586      TV Show    Action      Hindi          2009
# 590        5591        Movie    Action      Tamil          2019
# 595        5596      TV Show    Action      Tamil          2024
# 597        5598        Movie  Thriller     Telugu          2021
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 1                 165     7.300000        U/A     Canada  2023-03-23
# ...

# %%
#27. Filter content available in Hindi or English.

df[df["language"].isin(["Hindi","English"])]
# Out:
#      content_id content_type        genre language  release_year  \
# 5          5006        Movie        Drama    Hindi          2010
# 8          5009        Movie       Comedy  English          2005
# 11         5012      TV Show        Drama  English          2014
# 19         5020        Movie        Drama  English          2017
# 20         5021      TV Show       Action  English          2015
# ..          ...          ...          ...      ...           ...
# 586        5587        Movie  Documentary    Hindi          2011
# 588        5589      TV Show  Documentary  English          2013
# 591        5592        Movie       Sci-Fi  English          2005
# 596        5597        Movie       Sci-Fi    Hindi          2017
# 599        5600        Movie       Comedy  English          2024
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 5                 104     6.200000          A  Australia  2022-12-27
# ...

# %%
#28. Filter content with duration between 90 and 150 minutes.

df[df["duration_minutes"].between(90,150)]
# Out:
#      content_id content_type        genre   language  release_year  \
# 2          5003        Movie  Documentary  Malayalam          2024
# 5          5006        Movie        Drama      Hindi          2010
# 6          5007        Movie       Action    Kannada          2019
# 9          5010        Movie     Thriller    Kannada          2017
# 13         5014        Movie       Sci-Fi    Kannada          2020
# ..          ...          ...          ...        ...           ...
# 591        5592        Movie       Sci-Fi    English          2005
# 592        5593        Movie  Documentary      Tamil          2009
# 593        5594        Movie      Romance  Malayalam          2009
# 598        5599        Movie        Drama  Malayalam          2008
# 599        5600        Movie       Comedy    English          2024
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 2                 129     9.500000          A         UK  2023-10-05
# ...

# %%
#29. Create a new column popularity_score as views_millions + likes_millions.

df["popularity_score"] = df["views_millions"] + df["likes_millions"]
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                80     6.916961          U  Australia  2022-08-21
# 1               165     7.300000        U/A     Canada  2023-03-23
# 2               129     9.500000          A         UK  2023-10-05
# 3               169     4.600000        U/A      India  2023-09-04
# 4               157     8.100000        U/A  Australia  2024-01-05
#
#    views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 0           87.23                50.0            0.01             Basic
# ...

# %%
#30. Create a new column rating_category using apply().

def category_rating(x):
    if x >= 8:
        return "Excellent"
    elif x >= 6:
        return "Good"
    elif x >= 4:
        return "Average"
    else:
        return "Poor"

df['rating_category'] = df['imdb_rating'].apply(category_rating)
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                80     6.916961          U  Australia  2022-08-21
# 1               165     7.300000        U/A     Canada  2023-03-23
# 2               129     9.500000          A         UK  2023-10-05
# 3               169     4.600000        U/A      India  2023-09-04
# 4               157     8.100000        U/A  Australia  2024-01-05
#
#    views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 0           87.23                50.0            0.01             Basic
# ...

# %%
#31. Map subscription_plan to short codes.

plan_code = {"Basic" : "B", "Standard" : "S", "Mobile" : "M", "Premium" : "P"}

df["subscription_short_codes"] = df["subscription_plan"].map(plan_code)
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                80     6.916961          U  Australia  2022-08-21
# 1               165     7.300000        U/A     Canada  2023-03-23
# 2               129     9.500000          A         UK  2023-10-05
# 3               169     4.600000        U/A      India  2023-09-04
# 4               157     8.100000        U/A  Australia  2024-01-05
#
#    views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 0           87.23                50.0            0.01             Basic
# ...

# %%
#32. Map is_trending values to numerical format.

trending_value = {"No" : 0, "Yes" : 1}

df["trending_value"] = df["is_trending"].map(trending_value)
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country  added_date  \
# 0                80     6.916961          U  Australia  2022-08-21
# 1               165     7.300000        U/A     Canada  2023-03-23
# 2               129     9.500000          A         UK  2023-10-05
# 3               169     4.600000        U/A      India  2023-09-04
# 4               157     8.100000        U/A  Australia  2024-01-05
#
#    views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 0           87.23                50.0            0.01             Basic
# ...

# %%
#33. Count content by subscription_plan.

df["subscription_plan"].value_counts()
# Out:
# subscription_plan
# Basic       178
# Mobile      145
# Standard    140
# Premium     137
# Name: count, dtype: int64

# %%
#34. Identify top 5 contents based on popularity_score.

df.sort_values("popularity_score", ascending=False).head()
# Out:
#      content_id content_type    genre   language  release_year  \
# 403        5404        Movie  Romance  Malayalam          2015
# 299        5300      TV Show   Sci-Fi      Tamil          2014
# 521        5522        Movie   Comedy      Hindi          2012
# 572        5573      TV Show   Action    English          2012
# 210        5211      TV Show   Comedy  Malayalam          2015
#
#      duration_minutes  imdb_rating age_rating    country  added_date  \
# 403               117          4.6          A     Canada  2023-07-22
# 299               129          8.1          U  Australia  2021-06-02
# 521                67          7.2          U  Australia  2023-08-27
# 572                90          8.2        U/A  Australia  2022-10-09
# 210                74          7.1          U         UK  2023-04-10
#
#      views_millions  avg_watch_time_min  likes_millions subscription_plan  \
# 403          118.36           48.000000           14.22           Premium
# ...

# %%
#35. Group the data by content_type and count total content.

df.groupby("content_type").count()
# Out:
#               content_id  genre  language  release_year  duration_minutes  \
# content_type
# Movie                367    367       367           367               367
# TV Show              233    233       233           233               233
#
#               imdb_rating  age_rating  country  added_date  views_millions  \
# content_type
# Movie                 367         367      367         367             367
# TV Show               233         233      233         233             233
#
#               avg_watch_time_min  likes_millions  subscription_plan  \
# content_type
# Movie                        367             367                367
# TV Show                      233             233                233
#
#               is_trending  revenue_millions  popularity_score  \
# content_type
# Movie                 367               367               367
# TV Show               233               233               233
#
# ...

# %%
#36. Group the data by genre and calculate average imdb_rating.

df.groupby("genre")["imdb_rating"].mean()
# Out:
# genre
# Action         7.009606
# Comedy         6.963678
# Documentary    6.686848
# Drama          7.071357
# Romance        6.806641
# Sci-Fi         7.186156
# Thriller       6.640655
# Name: imdb_rating, dtype: float64

# %%
#37. Group the data by language and calculate average views_millions.

df.groupby("language")["views_millions"].mean()
# Out:
# language
# English      64.021650
# Hindi        63.005385
# Kannada      61.063214
# Malayalam    59.209717
# Tamil        63.118468
# Telugu       58.147609
# Name: views_millions, dtype: float64

# %%
#38. Group the data by subscription_plan and calculate average revenue.

df.groupby("subscription_plan")["revenue_millions"].mean()
# Out:
# subscription_plan
# Basic       25.284831
# Mobile      25.812690
# Premium     24.575912
# Standard    25.539071
# Name: revenue_millions, dtype: float64

# %%
#39. Group the data by country and count content.

df.groupby("country")["content_id"].count()
# Out:
# country
# Australia    134
# Canada       120
# India        121
# UK           124
# USA          101
# Name: content_id, dtype: int64

# %%
#40. Group the data by genre and calculate total revenue.

df.groupby("genre")["revenue_millions"].sum()
# Out:
# genre
# Action         2127.80
# Comedy         1928.84
# Documentary    2379.68
# Drama          2503.21
# Romance        1933.78
# Sci-Fi         2498.81
# Thriller       1813.79
# Name: revenue_millions, dtype: float64

# %%
#41. Group the data by content_type and calculate average duration.

df.groupby("content_type")["duration_minutes"].mean()
# Out:
# content_type
# Movie      118.948229
# TV Show    119.798283
# Name: duration_minutes, dtype: float64

# %%
#42. Group the data by is_trending and calculate average views.

df.groupby("is_trending")["views_millions"].mean()
# Out:
# is_trending
# No     63.072095
# Yes    58.372613
# Name: views_millions, dtype: float64

# %%
#43. Filter grouped genres having average imdb_rating greater than 7.5.

genre_avg_imdb_rating = df.groupby("genre")["imdb_rating"].mean()

# %%
genre_avg_imdb_rating[genre_avg_imdb_rating > 7.5]
# Out:
# Series([], Name: imdb_rating, dtype: float64)

# %%
#44. Filter grouped languages having more than 50 contents.

language_count = df.groupby("language")["content_id"].count()

# %%
language_count[language_count > 50]
# Out:
# language
# English      103
# Hindi        104
# Kannada       84
# Malayalam    106
# Tamil        111
# Telugu        92
# Name: content_id, dtype: int64

# %%
#45. Perform multiple aggregations on genre for views, likes, and revenue.

df.groupby('genre').agg({'views_millions': ['sum', 'mean', 'max'],
                         'likes_millions': ['sum', 'mean', 'max'],
                         'revenue_millions': ['sum', 'mean', 'max']})
# Out:
#             views_millions                    likes_millions                   \
#                        sum       mean     max            sum      mean    max
# genre
# Action             5470.61  62.880575  118.81         636.57  7.316897  15.00
# Comedy             3919.95  54.443750  119.04         534.90  7.429167  14.51
# Documentary        6280.93  62.809300  117.05         750.05  7.500500  14.89
# Drama              6088.93  60.889300  118.34         736.82  7.368200  14.99
# Romance            4749.64  65.063562  118.36         563.59  7.720411  14.97
# Sci-Fi             6024.91  63.420105  119.88         735.86  7.745895  14.85
# Thriller           4373.09  59.905342  119.66         523.03  7.164795  14.64
#
#             revenue_millions
#                          sum       mean    max
# genre
# Action               2127.80  24.457471  47.43
# Comedy               1928.84  26.789444  49.81
# Documentary          2379.68  23.796800  49.67
# ...

# %%
#46. Perform named aggregations on content_type.

df.groupby('content_type').agg(avg_duration=('duration_minutes', 'mean'),
                               total_views=('views_millions', 'sum'),
                               max_revenue=('revenue_millions', 'max'))
# Out:
#               avg_duration  total_views  max_revenue
# content_type
# Movie           118.948229     22564.59        49.81
# TV Show         119.798283     14343.47        49.67

# %%
#47. Perform named aggregations on country.

df.groupby('country').agg(total_content=('content_id', 'count'),
                          total_views=('views_millions', 'sum'),
                          avg_revenue=('revenue_millions', 'mean'))
# Out:
#            total_content  total_views  avg_revenue
# country
# Australia            134      8190.46    24.429403
# Canada               120      7222.81    27.538500
# India                121      7496.92    27.327438
# UK                   124      7325.82    23.920887
# USA                  101      6672.05    23.118218

# %%
df["added_date"] = pd.to_datetime(df["added_date"])

# %%
#48. Extract year from added_date.

df["year"]=df["added_date"].dt.year
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country added_date  ...  \
# 0                80     6.916961          U  Australia 2022-08-21  ...
# 1               165     7.300000        U/A     Canada 2023-03-23  ...
# 2               129     9.500000          A         UK 2023-10-05  ...
# 3               169     4.600000        U/A      India 2023-09-04  ...
# 4               157     8.100000        U/A  Australia 2024-01-05  ...
#
#    avg_watch_time_min  likes_millions  subscription_plan is_trending  \
# 0                50.0            0.01              Basic          No
# ...

# %%
#49. Extract month from added_date.

df["month"]=df["added_date"].dt.month
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country added_date  ...  \
# 0                80     6.916961          U  Australia 2022-08-21  ...
# 1               165     7.300000        U/A     Canada 2023-03-23  ...
# 2               129     9.500000          A         UK 2023-10-05  ...
# 3               169     4.600000        U/A      India 2023-09-04  ...
# 4               157     8.100000        U/A  Australia 2024-01-05  ...
#
#    likes_millions  subscription_plan  is_trending revenue_millions  \
# 0            0.01              Basic           No             9.82
# ...

# %%
##50. Extract month name from added_date.

df["month_name"]=df["added_date"].dt.month_name()
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country added_date  ...  \
# 0                80     6.916961          U  Australia 2022-08-21  ...
# 1               165     7.300000        U/A     Canada 2023-03-23  ...
# 2               129     9.500000          A         UK 2023-10-05  ...
# 3               169     4.600000        U/A      India 2023-09-04  ...
# 4               157     8.100000        U/A  Australia 2024-01-05  ...
#
#    subscription_plan  is_trending  revenue_millions popularity_score  \
# 0              Basic           No              9.82            87.24
# ...

# %%
#51. Extract day name from added_date.

df["day_name"]=df["added_date"].dt.day_name()
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country added_date  ...  \
# 0                80     6.916961          U  Australia 2022-08-21  ...
# 1               165     7.300000        U/A     Canada 2023-03-23  ...
# 2               129     9.500000          A         UK 2023-10-05  ...
# 3               169     4.600000        U/A      India 2023-09-04  ...
# 4               157     8.100000        U/A  Australia 2024-01-05  ...
#
#    is_trending  revenue_millions  popularity_score rating_category  \
# 0           No              9.82             87.24            Good
# ...

# %%
#52. Extract quarter from added_date.

df["quarter"]=df["added_date"].dt.quarter
df.head()
# Out:
#    content_id content_type        genre   language  release_year  \
# 0        5001        Movie      Romance      Tamil          2014
# 1        5002      TV Show       Action  Malayalam          2010
# 2        5003        Movie  Documentary  Malayalam          2024
# 3        5004      TV Show       Comedy     Telugu          2016
# 4        5005      TV Show  Documentary  Malayalam          2021
#
#    duration_minutes  imdb_rating age_rating    country added_date  ...  \
# 0                80     6.916961          U  Australia 2022-08-21  ...
# 1               165     7.300000        U/A     Canada 2023-03-23  ...
# 2               129     9.500000          A         UK 2023-10-05  ...
# 3               169     4.600000        U/A      India 2023-09-04  ...
# 4               157     8.100000        U/A  Australia 2024-01-05  ...
#
#    revenue_millions  popularity_score  rating_category  \
# 0              9.82             87.24             Good
# ...

# %%
#53. Group data by year and count content added.

df.groupby("year")["content_id"].count()
# Out:
# year
# 2021    191
# 2022    168
# 2023    183
# 2024     58
# Name: content_id, dtype: int64

# %%
#54. Group data by month name and calculate average views.

df.groupby("month_name")["views_millions"].mean()
# Out:
# month_name
# April        53.650517
# August       59.686579
# December     61.954167
# February     65.564400
# January      57.761587
# July         61.625333
# June         59.436744
# March        60.893235
# May          67.527609
# November     63.271750
# October      62.048723
# September    68.968462
# Name: views_millions, dtype: float64

# %%
#55. Group data by quarter and calculate average revenue.

df.groupby("quarter")["revenue_millions"].mean()
# Out:
# quarter
# 1    25.516575
# 2    25.243333
# 3    25.247445
# 4    25.168444
# Name: revenue_millions, dtype: float64

# %%
#56. Group data by day name and count content added.

df.groupby("day_name")["content_id"].count()
# Out:
# day_name
# Friday       95
# Monday       76
# Saturday     89
# Sunday       87
# Thursday     94
# Tuesday      83
# Wednesday    76
# Name: content_id, dtype: int64

# %%
#57. Identify the month with highest content additions.

df.groupby("month")["content_id"].count().sort_values(ascending=False).head(1)
# Out:
# month
# 3    68
# Name: content_id, dtype: int64

# %%
#58. Identify the quarter with highest average imdb_rating.

df.groupby("quarter")["imdb_rating"].mean().sort_values(ascending=False).head(1)
# Out:
# quarter
# 4    7.007672
# Name: imdb_rating, dtype: float64

# %%
#59. Group by year and genre and calculate average imdb_rating.

df.groupby(["year","genre"])["imdb_rating"].mean()
# Out:
# year  genre
# 2021  Action         6.973958
#       Comedy         7.292544
#       Documentary    6.216693
#       Drama          7.030510
#       Romance        6.846996
#       Sci-Fi         7.585185
#       Thriller       6.929167
# 2022  Action         6.986957
#       Comedy         6.712996
#       Documentary    6.927232
#       Drama          7.047797
#       Romance        6.868282
#       Sci-Fi         6.860302
#       Thriller       5.835000
# 2023  Action         7.075862
#       Comedy         6.995833
#       Documentary    7.182110
#       Drama          7.000707
#       Romance        6.578261
#       Sci-Fi         7.129911
#       Thriller       6.978815
# 2024  Action         6.943392
#       Comedy         6.680000
#       Documentary    6.180000
#       Drama          7.419724
#       Romance        7.245280
#       Sci-Fi         7.137500
#       Thriller       6.890560
# Name: imdb_rating, dtype: float64

# %%
#60. Group by language and year and calculate content count.

df.groupby(["language","year"])["content_id"].count()
# Out:
# language   year
# English    2021    29
#            2022    37
#            2023    29
#            2024     8
# Hindi      2021    36
#            2022    29
#            2023    28
#            2024    11
# Kannada    2021    29
#            2022    25
#            2023    24
#            2024     6
# Malayalam  2021    29
#            2022    24
#            2023    36
#            2024    17
# Tamil      2021    36
#            2022    28
#            2023    40
#            2024     7
# Telugu     2021    32
#            2022    25
#            2023    26
#            2024     9
# Name: content_id, dtype: int64

# %%
#61. Group by country and subscription_plan and calculate average revenue.

df.groupby(["country","subscription_plan"])["revenue_millions"].mean()
# Out:
# country    subscription_plan
# Australia  Basic                26.045238
#            Mobile               23.060645
#            Premium              23.974815
#            Standard             24.042353
# Canada     Basic                25.299189
#            Mobile               25.695667
#            Premium              28.850370
#            Standard             31.489231
# India      Basic                26.711714
#            Mobile               30.790769
#            Premium              25.912692
#            Standard             26.394706
# UK         Basic                23.178462
#            Mobile               24.560645
#            Premium              24.643235
#            Standard             23.149000
# USA        Basic                25.274400
#            Mobile               25.746296
#            Premium              18.653043
#            Standard             22.265769
# Name: revenue_millions, dtype: float64

# %%
#62. Filter grouped years with more than 100 contents.

content_count = df.groupby("year")["content_id"].count()
content_count[content_count > 100]
# Out:
# year
# 2021    191
# 2022    168
# 2023    183
# Name: content_id, dtype: int64

# %%
#63. Filter grouped genres with average revenue above 20 million.

avg_genre_revenue = df.groupby("genre")["revenue_millions"].mean()
avg_genre_revenue[avg_genre_revenue > 20]
# Out:
# genre
# Action         24.457471
# Comedy         26.789444
# Documentary    23.796800
# Drama          25.032100
# Romance        26.490137
# Sci-Fi         26.303263
# Thriller       24.846438
# Name: revenue_millions, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# content_id                           int64
# content_type                        object
# genre                               object
# language                            object
# release_year                         int64
# duration_minutes                     int64
# imdb_rating                        float64
# age_rating                          object
# country                             object
# added_date                  datetime64[ns]
# views_millions                     float64
# avg_watch_time_min                 float64
# likes_millions                     float64
# subscription_plan                   object
# is_trending                         object
# revenue_millions                   float64
# popularity_score                   float64
# rating_category                     object
# subscription_short_codes            object
# trending_value                       int64
# year                                 int32
# month                                int32
# ...

# %%
plt.hist(df["release_year"],edgecolor="black")
plt.title("Release Year Distribution using Histogram")
plt.xlabel("Release Year")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# This distribution shows that most of the genres are released between 2012.5 to 2014.
# Less genres are released between 2008 to 2010.5

# %%
plt.hist(df["duration_minutes"],edgecolor="black")
plt.title("Duration Minutes Distribution using Histogram")
plt.xlabel("Duration Minutes")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# This distribution shows that many genres have duration minutes in 80,100 and 120. Few genres have 90 minutes of duration.

# %%
plt.hist(df["imdb_rating"],edgecolor="black")
plt.title("imdb rating  Distribution using Histogram")
plt.xlabel("imdb rating ")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# This distribution shows that many genres have imdb rating of 7

# %%
plt.hist(df["views_millions"],edgecolor="black")
plt.title("views_millions Distribution using Histogram")
plt.xlabel("views_millions")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that many genres have 60, 90 and 100 millions viwes. Few grnres have 10 and 80 millions viwes

# %%
plt.hist(df["avg_watch_time_min"],edgecolor="black")
plt.title("avg_watch_time_min Distribution using Histogram")
plt.xlabel("avg_watch_time_min")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that many genres have average watch time of 80 minutes.
# Few genres have average watch time of 70,100 and 140 minutes

# %%
plt.hist(df["likes_millions"],edgecolor="black")
plt.title("likes_millions Distribution using Histogram")
plt.xlabel("likes_millions")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that many genres have 13 millions likes.
# Few genres have 11 and 14 millions like

# %%
plt.hist(df["revenue_millions"],edgecolor="black")
plt.title("revenue_millions Distribution using Histogram")
plt.xlabel("revenue_millions")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that many genres have 35 to 40 millions revenue. Few genres have 5 and 40 to 50 millions revenue

# %%
plt.hist(df["popularity_score"],edgecolor="black")
plt.title("popularity_score Distribution using Histogram")
plt.xlabel("popularity_score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that many genres have popularity score of 100. Few genres have popularity score of 10 and 120.

# %%
plt.hist(df["trending_value"],edgecolor="black")
plt.title("trending_value Distribution using Histogram")
plt.xlabel("trending_value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The distribution shows that most of the genres have 0 trending value it means that many genres are not trending.
# Few genres are on trending.

# %%
sns.countplot(x=df["content_type"],data=df)
plt.title("Countplot for content_type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Movie has the highest count in content type and TV Show has lowest count

# %%
sns.countplot(x=df["genre"],data=df)
plt.title("Countplot for Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Documentary and Drama has the highest count in genre and Romance, Comedy and Thriller has lowest count

# %%
sns.countplot(x=df["language"],data=df)
plt.title("Countplot for Language")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Tamil has the highest count in language and Kannada has the lowest count

# %%
sns.countplot(x=df["age_rating"],data=df)
plt.title("Countplot for age_rating")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that U has the highest count in age rating and U/A has the lowest count

# %%
sns.countplot(x=df["country"],data=df)
plt.title("Countplot for country")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Australia has the highest count of genre and USA has the lowest count

# %%
sns.countplot(x=df["subscription_plan"],data=df)
plt.title("Countplot for subscription_plan")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Basic plan has the highest count in subscription plan and Standard and Premium has the lowest count

# %%
sns.countplot(x=df["is_trending"],data=df)
plt.title("Countplot for is_trending")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that Many genres are not trending only few genres are trending, No has the highest count and Yes has lowest count

# %%
sns.countplot(x=df["genre"], hue="content_type", data=df)
plt.title("Genre wise Content Type count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The distribution shows that many genres content type are movie.
# Action genre have highest content type of TV Show.
# Romance,Documentary,Comedy,Drama,Sci-Fi and Thriller have highest content type Movie
# Documentary has highest Movie type compared to others

# %%
sns.countplot(x=df["language"], hue="genre", data=df)
plt.title("Language wise Genre count")
plt.xlabel("Language")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that In Tamil Drama and Sci-Fi has the highest and Thriller has the lowest count.
# - In Malayalam Drama and Action has the highest count and Thriller has the lowest count.
# - In Telugu Sci-Fi has highest count and Drama has the lowest count.
# - In Hindi Documentary has the highest count and thriller has the lowest count.
# - In Kannada Documentary and Thriller has the highest count and Romance has the lowest count.
# - In English Drama has the highest count and Romance has the lowest count.

# %%
sns.countplot(x=df["genre"], hue="release_year", data=df)
plt.title("Genre wise Year count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that In Romance many genre are released in year 2012.
# - In Action many genre are released in year 2016.
# - In Documentary many genre are released in year 2024.
# - In Comedy many genre are released in year 2012 and 2016.
# - In Drama many genre are released in year 2012,2016,2020.
# - In Sci-Fi many genre are released in year 2016.
# - In Thriller many genre are released in year 2024.

# %%
sns.countplot(x=df["genre"], hue="age_rating", data=df)
plt.title("Genre wise Age count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that In Romance the age count of U is highest around 30 and U/A has lowest count around 20.
# - In Action the age count of A is highest around 38 and U has lowest count around 23.
# - In Documentary the age count of U is highest around 38 and A has lowest count around 29.
# - In Comedy the age count of A is highest around 28 and U/A has lowest count around 26.
# - In Drama the age count of U is highest around 36 and A has lowest around 29.
# - In Si-Fi the age count of U is highest around 40 and A has lowest count around 28.
# - In Thriller the age count of U/A is highest around 28 and A has lowest count 22.

# %%
sns.countplot(x=df["country"], hue="genre", data=df)
plt.title("Country wise Genre count")
plt.xlabel("Country")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that In Australia Drama has highest count around 28 and Thriller has the lowest count.
# - In Canada Documentary has the highest count around 23 and Romance has lowest count around 14.
# - In UK Drama has the highest count around 30 and Comedy has lowest count around 10.
# - In India Sci-Fi has the highest count around 22 and Documentary has the lowest count around 15.
# - In USA Documentary has the highest count around 19 and Thriller has the lowest count around 10.

# %%
sns.countplot(x=df["genre"], hue="subscription_plan", data=df)
plt.title("Genre wise Plan count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that Romance has the highest count of Basic Subscription plan and lowest count of standard plan.
# - Action has the highest count of Basic plan and lowest count of Premium plan.
# - Documentary has the highest count of Basic plan and lowest count of Mobile plan.
# - Comedy has the highest count of Basic plan and lowest count of Premium plan.
# - Drama has the highest count of Basic plan and lowest count of Standard plan.
# - Sci-Fi has the highest count of Basic plan and lowest count of Standard plan.
# - Thriller has the highest count of Standard and Mobile plan and lowest count of Basic plan.

# %%
sns.countplot(x=df["genre"], hue="is_trending", data=df)
plt.title("Genre wise Trending count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution show that In Romance many shows are not trending around 49 and around 25 shows are trending.
# - In Action around 60 shows are not trending and around 26 shows are trending.
# - In Documentary around 62 shows are not trending and around 38 shows are trending.
# - In Comedy around 49 shows are not trending and around 39 shows are trending.
# - In Drama around 64 shows are not trending and around 48 shows are trending.
# - In Sci-Fi around 65 shows are not trending and around 29 shows are trending.
# - In Thriller around 52 shows are not trending and around 20 shows are trending.

# %%
sns.countplot(x=df["genre"], hue="rating_category", data=df)
plt.title("Genre wise rating count")
plt.xlabel("Genre")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The distribution shows that In Romance highest rating count is Good and low is Excellent.
# - In Action highest rating count is Good and low is Average.
# - In Documentary highest rating count is Good and low is Excellent.
# - In Comedy highest rating count is Good and low is Average.
# - In Drama highest rating count is Good and low is Average.
# - In Sci-Fi highest rating count is Good and low is Average.
# - In Thriller highest rating count is Good and low is Excellent.

# %%
plt.scatter(df["views_millions"],df["popularity_score"])
plt.xlabel("views_millions")
plt.ylabel("popularity_score")
plt.title("views_millions wise popularity_score")
plt.show()

# %% [markdown]
# The visualization shows that relationship between the two features genre and Duration minutes is positive relationship as the views increases popularity score also increases.

# %%
sns.regplot(x="duration_minutes",y="views_millions",data=df)
plt.title("Distribution of duration_minutes compared to views_millions")
plt.xlabel("duration_minutes")
plt.ylabel("views_millions")
plt.show()

# %% [markdown]
# The visualization indicates an downward trend in duration minutes and views million, which means that there is an negative relationship as the duration minutes increases views decreases

# %%
sns.regplot(x="duration_minutes",y="likes_millions",data=df)
plt.title("Distribution of duration_minutes compared to likes_millions")
plt.xlabel("duration_minutes")
plt.ylabel("likes_millions")
plt.show()

# %% [markdown]
# The visualization indicates an downward trend in duration minutes and likes million, which means that there is an negative relationship as the duration minutes increases likes decreases

# %%
sns.regplot(x="imdb_rating",y="revenue_millions",data=df)
plt.title("Distribution of imdb_rating compared to revenue_millions")
plt.xlabel("imdb_rating")
plt.ylabel("revenue_millions")
plt.show()

# %% [markdown]
# The visualization indicates an upward trend in imdb rating and revenue, which means there is positive relationship as the imdb rating increases revenue also increases

# %%
sns.regplot(x="likes_millions",y="popularity_score",data=df)
plt.title("Distribution of likes_millions compared to popularity_score")
plt.xlabel("likes_millions")
plt.ylabel("popularity_score")
plt.show()

# %% [markdown]
# The visualization indicates an upward trend in likes and popularity score, which means there is positive relationship as the likes increases popularity score also increases

# %%
sns.regplot(x="revenue_millions",y="popularity_score",data=df)
plt.title("Distribution of revenue_millions compared to popularity_score")
plt.xlabel("revenue_millions")
plt.ylabel("popularity_score")
plt.show()

# %% [markdown]
# The visualization indicates an downward trend in revenue and popularity score, which means that there is an negative relationship as the revenue increases popularity score decreases

# %%
sns.regplot(x="views_millions",y="revenue_millions",data=df)
plt.title("Distribution of views_millions compared to popularity_score")
plt.xlabel("views_millions")
plt.ylabel("popularity_score")
plt.show()

# %% [markdown]
# The visualization here indicates an downward trend in views and revenue Feature, which means that there is negative relationship as the views increases revenue decreases.

# %%
sns.regplot(x="views_millions",y="popularity_score",data=df)
plt.title("Distribution of views_millions compared to popularity_score")
plt.xlabel("views_millions")
plt.ylabel("popularity_score")
plt.show()

# %% [markdown]
# The visualization here indicates an upward trend in views and popularity score, which means there is a positive relationship as the views increases popularity score also increases

# %%
sns.boxplot(x="subscription_plan", y="avg_watch_time_min", data=df)
plt.title("Distribution of subscription_plan Compared to avg_watch_time_min")
plt.xlabel("subscription_plan")
plt.ylabel("avg_watch_time_min")
plt.show()

# %% [markdown]
# The visualization indicates that the Basic plan have the highest medium sale whereas standard have low medium sale. There are no outliers in any plan that means no such plan exceeds the plan amount.

# %%
sns.boxplot(x="genre", y="release_year", data=df)
plt.title("Distribution of genre Compared to release_year")
plt.xlabel("genre")
plt.ylabel("release_year")
plt.show()

# %% [markdown]
# The visualization shows that Genre like Documentary,Drama,Thriller has the highest median and Genre like Romance have the low median

# %%
sns.boxplot(x="language", y="views_millions", data=df)
plt.title("Distribution of language Compared to views_millions")
plt.xlabel("language")
plt.ylabel("views_millions")
plt.show()

# %% [markdown]
# The visualization shows that languages like Tamil,Hindi and English has the highest median of views and languages like Malayalam, Telugu and Kannada have lowest median of viwes

# %%
sns.boxplot(x="language", y="revenue_millions", data=df)
plt.title("Distribution of language Compared to revenue_millions")
plt.xlabel("language")
plt.ylabel("revenue_millions")
plt.show()

# %% [markdown]
# The visualization indicates that languages like Telugu and English has the highest median of revenue and languages like Tamil,Malayalam, Hindi and English has lowest median of revenue

# %%
sns.boxplot(x="genre", y="revenue_millions", data=df)
plt.title("Distribution of genre Compared to revenue_millions")
plt.xlabel("genre")
plt.ylabel("revenue_millions")
plt.show()

# %% [markdown]
# The visualization indicates that genres like Comedy, Romance and Sci-Fi has highest median of revenue and genres like Action,Documentary,Drama have lowest median of revenue

# %%
sns.pairplot(df[["views_millions","likes_millions","revenue_millions","popularity_score"]])

# %% [markdown]
# The visualization shows that Views Millions is related with popularity score as the views increases popularity score also increases.
# Likes and revenue is not related with any one.
# Popularity score is related with views.
# Popularity score is driven by Views.

# %%
sns.scatterplot(x="duration_minutes", y="avg_watch_time_min", hue="content_type", data=df)
plt.title("Scatterplot for analaysing duration_minutes and avg_watch_time_min with respect to content_type")
plt.xlabel("duration_minutes")
plt.ylabel("avg_watch_time_min")
plt.show()

# %%
sns.scatterplot(x="imdb_rating", y="views_millions", hue="age_rating", data=df)
plt.title("Scatterplot for analaysing imdb_rating and views_millions with respect to age_rating")
plt.xlabel("imdb_rating")
plt.ylabel("views_millions")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="genre",y="imdb_rating",hue="content_type",data=df)
plt.title("Boxplot for genre and imdb_rating with respect to content_type")
plt.xlabel("genre")
plt.ylabel("imdb_rating")
plt.show()

# %% [markdown]
# The visualization indicates that Genres like Romance,Comedy,Drama and Thriller have highest median of content type TV Show and Genres like Action,Documentary and Sci-Fi have lowest median of content type Movie

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="age_rating",y="avg_watch_time_min",hue="subscription_plan",data=df)
plt.title("Boxplot for age_rating and avg_watch_time_min with respect to subscription_plan")
plt.xlabel("age_rating")
plt.ylabel("avg_watch_time_min")
plt.show()

# %% [markdown]
# The visualization indicates that age_rating U have the highest median of Premium subscription plan and lowest median of Basic subscription plan.
# Age rating U/A have the highest median of standard subscription plan and lowest median of Premium subscription plan.
# Age rating A have highest median of Standard plan and lowest median of Mobile plan.

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="genre",y="views_millions",hue="is_trending",data=df)
plt.title("Boxplot for genre and views_millions with respect to is_trending")
plt.xlabel("genre")
plt.ylabel("views_millions")
plt.show()

# %% [markdown]
# The visualization indicates that all genres have highest median of Not trending, which means that only few shows in all genres are on trending

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="subscription_plan",y="revenue_millions",hue="content_type",data=df)
plt.title("Boxplot for subscription_plan and revenue_millions with respect to content_type")
plt.xlabel("subscription_plan")
plt.ylabel("revenue_millions")
plt.show()

# %% [markdown]
# The visualization indicates that subscription plan plans like Basic and Mobile have highest median of content type TV Show and Standard plan have highest median of content type Movie.
# Premium plan have slightly high median of Movie type than TV Show.

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="content_type",y="imdb_rating",hue="genre",data=df)
plt.title("Boxplot for content_type and imdb_rating with respect to genre")
plt.xlabel("content_type")
plt.ylabel("imdb_rating")
plt.show()

# %% [markdown]
# The visualization indicates that Movie type have highest median rating for Drama and lowest median rating for Romance.
# TV Show have highest median rating for Thriller and lowest median rating for Documentary.

# %%
ct1 = pd.crosstab(df["country"],df["subscription_plan"],values=df["revenue_millions"],aggfunc='sum')
ct1
# Out:
# subscription_plan    Basic  Mobile  Premium  Standard
# country
# Australia          1093.90  714.88   647.32    817.44
# Canada              936.07  770.87   778.96    818.72
# India               934.91  800.56   673.73    897.42
# UK                  903.96  761.38   837.87    462.98
# USA                 631.86  695.15   429.02    578.91

# %%
ct1.plot(kind="bar",figsize=(10,8))
plt.title("Distribution of country wise total revenue with respect to subscription plan")
plt.xlabel("country")
plt.ylabel("Total revenue")
plt.show()

# %% [markdown]
# The visualization shows that Austraila, Canada, India and Uk have highest revenue on Basic plans and USA have highest revenue on Mobile plans.

# %%
ct2 = pd.crosstab(df["genre"],df["content_type"],values=df["imdb_rating"],aggfunc='mean')
ct2
# Out:
# content_type     Movie   TV Show
# genre
# Action        7.066300  6.954200
# Comedy        6.788560  7.313913
# Documentary   6.770909  6.516179
# Drama         6.963239  7.220663
# Romance       6.687797  6.997640
# Sci-Fi        7.268506  7.072924
# Thriller      6.611134  6.709091

# %%
ct2.plot(kind="bar",figsize=(8,6))
plt.title("Distribution of genre wise imdb rating with respect to content type")
plt.xlabel("genre")
plt.ylabel("Total Rating")
plt.show()

# %% [markdown]
# The visualization shows that Comedy, Drama, Romance and Thriller have highest rating on content type TV Show.
# Action, Documentary and Sci-Fi have highest rating on Movie type.
